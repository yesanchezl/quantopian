# %% [markdown]
# ## Run lesson 6 adding portfolio to main algorithm

# %%
bt = get_backtest('5e6edb0ee8552f459fe4572c')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:13|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-13</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>11</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.395%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.374%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.214%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.41</td>
#     </tr>
#     <tr>
# ...
