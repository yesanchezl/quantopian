# %%
bt = get_backtest('5e781a4ebdd53c45a64e4b5e')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:11|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-06-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-06-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.905%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>7.97%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>16.226%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
# ...
